# %%
import pickle as pkl
import pandas as pd
import tensorflow as tf #pythorch
import numpy as np

# %%
with open("2018-04-01.pkl", "rb") as f:
    object = pkl.load(f)
    
df1 = pd.DataFrame(object)
df1.to_csv(r'file.csv')

with open("2018-04-02.pkl", "rb") as f:
    object = pkl.load(f)
    
df2 = pd.DataFrame(object)
df2.to_csv(r'file.csv')

with open("2018-04-03.pkl", "rb") as f:
    object = pkl.load(f)
    
df3 = pd.DataFrame(object)
df3.to_csv(r'file.csv')

with open("2018-04-04.pkl", "rb") as f:
    object = pkl.load(f)
    
df4 = pd.DataFrame(object)
df4.to_csv(r'file.csv')

with open("2018-04-05.pkl", "rb") as f:
    object = pkl.load(f)
    
df5 = pd.DataFrame(object)
df5.to_csv(r'file.csv')

with open("2018-04-06.pkl", "rb") as f:
    object = pkl.load(f)
    
df6 = pd.DataFrame(object)
df6.to_csv(r'file.csv')

with open("2018-04-07.pkl", "rb") as f:
    object = pkl.load(f)
    
df7 = pd.DataFrame(object)
df7.to_csv(r'file.csv')

with open("2018-04-08.pkl", "rb") as f:
    object = pkl.load(f)
    
df8 = pd.DataFrame(object)
df8.to_csv(r'file.csv')

with open("2018-04-09.pkl", "rb") as f:
    object = pkl.load(f)
    
df9 = pd.DataFrame(object)
df9.to_csv(r'file.csv')

with open("2018-04-10.pkl", "rb") as f:
    object = pkl.load(f)
    
df10 = pd.DataFrame(object)
df10.to_csv(r'file.csv')

with open("2018-04-11.pkl", "rb") as f:
    object = pkl.load(f)
    
df11 = pd.DataFrame(object)
df11.to_csv(r'file.csv')

with open("2018-04-12.pkl", "rb") as f:
    object = pkl.load(f)
    
df12 = pd.DataFrame(object)
df12.to_csv(r'file.csv')

with open("2018-04-13.pkl", "rb") as f:
    object = pkl.load(f)
    
df13 = pd.DataFrame(object)
df13.to_csv(r'file.csv')

with open("2018-04-14.pkl", "rb") as f:
    object = pkl.load(f)
    
df14 = pd.DataFrame(object)
df14.to_csv(r'file.csv')

with open("2018-04-15.pkl", "rb") as f:
    object = pkl.load(f)
    
df15 = pd.DataFrame(object)
df15.to_csv(r'file.csv')

with open("2018-04-16.pkl", "rb") as f:
    object = pkl.load(f)
    
df16 = pd.DataFrame(object)
df16.to_csv(r'file.csv')

with open("2018-04-17.pkl", "rb") as f:
    object = pkl.load(f)
    
df17 = pd.DataFrame(object)
df17.to_csv(r'file.csv')

with open("2018-04-18.pkl", "rb") as f:
    object = pkl.load(f)
    
df18 = pd.DataFrame(object)
df18.to_csv(r'file.csv')
with open("2018-04-18.pkl", "rb") as f:
    object = pkl.load(f)
    
df19 = pd.DataFrame(object)
df19.to_csv(r'file.csv')
with open("2018-04-19.pkl", "rb") as f:
    object = pkl.load(f)
    
df20 = pd.DataFrame(object)
df20.to_csv(r'file.csv')
with open("2018-04-20.pkl", "rb") as f:
    object = pkl.load(f)
    
df21 = pd.DataFrame(object)
df21.to_csv(r'file.csv')
with open("2018-04-21.pkl", "rb") as f:
    object = pkl.load(f)
    
df22 = pd.DataFrame(object)
df22.to_csv(r'file.csv')
with open("2018-04-22.pkl", "rb") as f:
    object = pkl.load(f)
    
df23 = pd.DataFrame(object)
df23.to_csv(r'file.csv')
with open("2018-04-23.pkl", "rb") as f:
    object = pkl.load(f)
    
df24 = pd.DataFrame(object)
df24.to_csv(r'file.csv')
with open("2018-04-24.pkl", "rb") as f:
    object = pkl.load(f)
    
df25 = pd.DataFrame(object)
df25.to_csv(r'file.csv')
with open("2018-04-25.pkl", "rb") as f:
    object = pkl.load(f)
    
df26 = pd.DataFrame(object)
df26.to_csv(r'file.csv')
with open("2018-04-26.pkl", "rb") as f:
    object = pkl.load(f)
    
df27 = pd.DataFrame(object)
df27.to_csv(r'file.csv')
with open("2018-04-27.pkl", "rb") as f:
    object = pkl.load(f)
    
df28 = pd.DataFrame(object)
df28.to_csv(r'file.csv')
with open("2018-04-28.pkl", "rb") as f:
    object = pkl.load(f)
    
df29 = pd.DataFrame(object)
df29.to_csv(r'file.csv')
with open("2018-04-29.pkl", "rb") as f:
    object = pkl.load(f)
    
df30 = pd.DataFrame(object)
df30.to_csv(r'file.csv')
with open("2018-04-30.pkl", "rb") as f:
    object = pkl.load(f)

# %%
X = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30])
display(X[["TRANSACTION_ID","TX_DATETIME","CUSTOMER_ID","TERMINAL_ID","TX_AMOUNT","TX_FRAUD"]])
# Out:
#         TRANSACTION_ID         TX_DATETIME CUSTOMER_ID TERMINAL_ID  TX_AMOUNT  \
# 0                    0 2018-04-01 00:00:31         596        3156      57.16
# 1                    1 2018-04-01 00:02:10        4961        3412      81.51
# 2                    2 2018-04-01 00:07:56           2        1365     146.00
# 3                    3 2018-04-01 00:09:29        4128        8737      64.49
# 4                    4 2018-04-01 00:10:34         927        9906      50.99
# ...                ...                 ...         ...         ...        ...
# 278297          278297 2018-04-29 23:52:15         691         392      11.24
# 278298          278298 2018-04-29 23:52:29        4974        7931     125.06
# 278299          278299 2018-04-29 23:54:19        1469         712     226.61
# 278300          278300 2018-04-29 23:55:31         510        9154      49.76
# 278301          278301 2018-04-29 23:56:06        4990        5421     112.88
#
#         TX_FRAUD
# ...

# %%
T = pd.Series(X.groupby('CUSTOMER_ID')['TX_AMOUNT'].mean())
print(max(X["TX_AMOUNT"]))
print(min(X["TX_AMOUNT"]))
print(T)
# Out:
# 947.4
# 0.0
# CUSTOMER_ID
# 0       58.002459
# 1       50.411885
# 2       81.922759
# 3       10.151429
# 4       80.032407
#           ...
# 4995    52.577895
# 4996    15.169740
# 4997    53.093774
# 4998    98.784343
# 4999    39.966667
# Name: TX_AMOUNT, Length: 4955, dtype: float64

# %%
X=X[['CUSTOMER_ID','TERMINAL_ID','TX_AMOUNT','TX_FRAUD']]
X['TERMINAL_ID']=(X['TERMINAL_ID']-X['TERMINAL_ID'].min())/(X['TERMINAL_ID'].max()-X['TERMINAL_ID'].min())
X['TX_AMOUNT']=(X['TX_AMOUNT']-X['TX_AMOUNT'].min())/(X['TX_AMOUNT'].max()-X['TX_AMOUNT'].min())
display(X)
# Out:
#        CUSTOMER_ID TERMINAL_ID  TX_AMOUNT  TX_FRAUD
# 0              596    0.315632   0.060334         0
# 1             4961    0.341234   0.086035         0
# 2                2    0.136514   0.154106         0
# 3             4128    0.873787   0.068071         0
# 4              927    0.990699   0.053821         0
# ...            ...         ...        ...       ...
# 278297         691    0.039204   0.011864         0
# 278298        4974    0.793179   0.132003         0
# 278299        1469    0.071207   0.239191         1
# 278300         510    0.915492   0.052523         0
# 278301        4990    0.542154   0.119147         0
#
# [287918 rows x 4 columns]

# %%
a = []
b = []
c = []
for i in T.index:
    a.extend([X[X['CUSTOMER_ID'] == i].to_numpy()[:,1]])
    b.extend([X[X['CUSTOMER_ID'] == i].to_numpy()[:,2]])
    c.extend([X[X['CUSTOMER_ID'] == i].to_numpy()[:,3]])

# %%
e = []
f = []
g = []
for i in range(len(a)):
    if len(a[i])>40 and len(a[i])<50:
        e.append(a[i])
        f.append(b[i])
        g.append(c[i])
    elif len(a[i])>= 50:
        e.append(a[i][0:49])
        f.append(b[i][0:49])
        g.append(c[i][0:49])

# %%
a1=[]
a2=[]
for i in range(len(g)):
    if sum(g[i])==0:
        a1.append(i)
    else:
        a2.append(i)

print(len(g))
print(len(a1))
print(len(a2))
# Out:
# 3194
# 2842
# 352

# %%
a2
# Out:
# [7,
#  10,
#  12,
#  15,
#  20,
#  41,
#  43,
#  118,
#  125,
#  127,
#  131,
#  135,
#  136,
#  144,
#  149,
#  151,
#  157,
#  162,
#  167,
#  214,
#  220,
#  223,
#  234,
#  238,
#  240,
#  249,
#  254,
#  256,
#  286,
#  314,
#  320,
#  321,
#  325,
#  326,
#  331,
#  333,
#  343,
#  374,
#  384,
#  389,
#  390,
#  409,
#  411,
#  414,
#  415,
#  417,
#  433,
#  437,
#  446,
#  449,
#  450,
#  462,
#  463,
#  466,
#  481,
#  487,
#  503,
#  508,
#  515,
#  517,
#  524,
#  537,
#  539,
#  550,
#  564,
#  565,
#  567,
#  572,
#  580,
#  596,
#  610,
#  612,
#  615,
#  616,
#  639,
#  649,
#  654,
#  657,
#  660,
#  674,
#  681,
#  695,
#  699,
#  703,
#  705,
#  720,
#  727,
#  739,
#  740,
#  749,
#  766,
#  769,
#  770,
#  771,
#  777,
#  783,
#  802,
#  807,
#  811,
#  814,
#  822,
#  831,
#  849,
#  872,
#  885,
#  888,
#  889,
#  905,
#  907,
#  925,
#  928,
#  944,
#  946,
#  954,
#  960,
#  971,
#  977,
#  1001,
#  1007,
#  1031,
#  1042,
#  1079,
#  1083,
#  1088,
#  1101,
# ...

# %%
e1 = []
f1 = []
g1 = []
j=1
while j<8:
    for i in range(len(a2)):
        e1.append(e[a2[i]])
        f1.append(f[a2[i]])
        g1.append(g[a2[i]])
    j +=1

# %%
for i in range(len(e1)):
    e.append(e1[i])
    f.append(f1[i])
    g.append(g1[i])

# %%
import matplotlib.pyplot as plt
#plot each series
plt.plot(f[30],label="[31]")
plt.plot(f[567],label="[568]")
plt.plot(f[2003],label="[2004]")
plt.plot(f[1023],label="[1024]")
plt.plot(f[3006],label="[3007]")
plt.legend(title='Montos')

#display plot
plt.show()

# %%
import matplotlib.pyplot as plt
#plot each series
plt.plot(e[30],label="[31]")
plt.plot(e[567],label="[568]")
plt.plot(e[2003],label="[2004]")
plt.plot(e[1023],label="[1024]")
plt.plot(e[3006],label="[3007]")
plt.legend(title='Terminal ID')

#display plot
plt.show()

# %%
import matplotlib.pyplot as plt
#plot each series
plt.plot(g[30],label="[31]")
plt.plot(g[567],label="[568]")
plt.plot(g[2003],label="[2004]")
plt.plot(g[1023],label="[1024]")
plt.plot(g[3006],label="[3007]")
plt.legend(title='Fraude')

#display plot
plt.show()

# %%
padded_inputs1 = tf.keras.preprocessing.sequence.pad_sequences(
    e, padding="post", maxlen=None, dtype='int32', value=-1.0)
padded_inputs2 = tf.keras.preprocessing.sequence.pad_sequences(
    f, padding="post", maxlen=None, dtype='float32', value=-1.0)
padded_outputs = tf.keras.preprocessing.sequence.pad_sequences(
    g, padding="post", maxlen=None, dtype='int32', value=1.0)
print(padded_inputs1.shape)
print(padded_inputs2.shape)
print(padded_outputs.shape)
print(5658*49)
# Out:
# (5658, 49)
# (5658, 49)
# (5658, 49)
# 277242

# %%
x_train1 = padded_inputs1.reshape(-1,1,49)
x_train2  = padded_inputs2.reshape(-1,1,49)
y_train  = padded_outputs.reshape(-1,1,49)
print(y_train.shape)
# Out:
# (5658, 1, 49)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Masking,Dense,Bidirectional,Input,LSTM,Embedding,SimpleRNN

# %%
monto_input = tf.keras.Input(shape=(1,49,), name="monto")

receptor_input = tf.keras.Input(shape=(1,49,), name="receptor")

monto_capa = tf.keras.layers.Masking(mask_value=-1.0)(monto_input)

receptor_capa = tf.keras.layers.Masking(mask_value=-1.0)(receptor_input)

monto_capa = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(49,return_sequences =True, input_shape = (1,49,)))(monto_capa)

receptor_capa = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(49,return_sequences =True, input_shape = (1,49,)))(receptor_capa)

x = tf.keras.layers.average([monto_capa, receptor_capa])

#x = tf.keras.layers.Dense(49)(x)

#x= tf.keras.layers.LSTM(49,return_sequences=True)(x)

x = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(49))(x)

clase_pred = tf.keras.layers.Dense(49, activation='sigmoid' ,name="clase")(x)

model = tf.keras.Model(
    inputs=[monto_input,receptor_input],
    outputs=[clase_pred],
)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=[tf.keras.losses.BinaryCrossentropy()],
    metrics=['accuracy'],
)

# %%
y_train[:,0,0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.utils import class_weight 
class_weights = []
for i in range(len(y_train[1,0,:])):
    class_weights.append(class_weight.compute_class_weight(class_weight = 'balanced',
                                                  classes = np.unique(y_train[:,0,i]),
                                                  y=np.array(y_train[:,0,i])))

# %%
range(1,49)
# Out:
# range(1, 49)

# %%
x=list(range(49))
final= dict()
y = np.insert(class_weights[0], 1, 0)
final[0] = y
for i in range(1,49):
    final[x[i]] = class_weights[i]


print(final)
# Out:
# {0: array([1., 0.]), 1: array([  0.50141794, 176.8125    ]), 2: array([  0.50141794, 176.8125    ]), 3: array([ 0.50355999, 70.725     ]), 4: array([ 0.50572041, 44.203125  ]), 5: array([ 0.50427807, 58.9375    ]), 6: array([ 0.50427807, 58.9375    ]), 7: array([ 0.50572041, 44.203125  ]), 8: array([ 0.50644468, 39.29166667]), 9: array([ 0.50717103, 35.3625    ]), 10: array([ 0.50427807, 58.9375    ]), 11: array([ 0.50862999, 29.46875   ]), 12: array([ 0.50862999, 29.46875   ]), 13: array([ 0.51083424, 23.575     ]), 14: array([ 0.50355999, 70.725     ]), 15: array([ 0.50862999, 29.46875   ]), 16: array([ 0.50789946, 32.14772727]), 17: array([ 0.50717103, 35.3625    ]), 18: array([ 0.50644468, 39.29166667]), 19: array([ 0.50789946, 32.14772727]), 20: array([ 0.51083424, 23.575     ]), 21: array([ 0.51083424, 23.575     ]), 22: array([ 0.51157324, 22.1015625 ]), 23: array([ 0.50936262, 27.20192308]), 24: array([ 0.51157324, 22.1015625 ]), 25: array([ 0.51083424, 23.575     ]), 26: arr
# ...

# %%
model.fit(
    {"monto": x_train1, "receptor": x_train2},
    {"clase": y_train},
    epochs = 1000,
    batch_size = 32,
    validation_split = 0.3,
    #class_weight = final
)
#model.evaluate()
# Out:
# Epoch 1/1000
# 124/124 [==============================] - 51s 110ms/step - loss: 0.3233 - accuracy: 0.0144 - val_loss: 0.2530 - val_accuracy: 0.0200
# Epoch 2/1000
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0945 - accuracy: 0.0139 - val_loss: 0.2227 - val_accuracy: 0.0200
# Epoch 3/1000
# 124/124 [==============================] - 1s 9ms/step - loss: 0.0763 - accuracy: 0.0141 - val_loss: 0.1999 - val_accuracy: 0.0200
# Epoch 4/1000
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0691 - accuracy: 0.0149 - val_loss: 0.1934 - val_accuracy: 0.0224
# Epoch 5/1000
# 124/124 [==============================] - 1s 9ms/step - loss: 0.0653 - accuracy: 0.0144 - val_loss: 0.1855 - val_accuracy: 0.0224
# Epoch 6/1000
# 124/124 [==============================] - 1s 9ms/step - loss: 0.0626 - accuracy: 0.0141 - val_loss: 0.1832 - val_accuracy: 0.0165
# Epoch 7/1000
# ...

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# monto (InputLayer)              [(None, 1, 49)]      0
# __________________________________________________________________________________________________
# receptor (InputLayer)           [(None, 1, 49)]      0
# __________________________________________________________________________________________________
# masking (Masking)               (None, 1, 49)        0           monto[0][0]
# __________________________________________________________________________________________________
# masking_1 (Masking)             (None, 1, 49)        0           receptor[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 1, 98)        38808       masking[0][0]
# ...

# %%
Q=model.predict([x_train1,x_train2])

# %%
Q[2018,0,:]#2171
# Out:
# array([7.1730689e-29, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        6.6092552e-20, 1.8555041e-30, 0.0000000e+00, 0.0000000e+00,
#        3.8201339e-24, 1.3115501e-30, 3.3198533e-15, 1.4702717e-25,
#        0.0000000e+00, 5.1006124e-29, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 1.1595183e-26, 5.1470600e-19,
#        7.8771655e-16, 9.9999899e-01, 0.0000000e+00, 1.4435224e-34,
#        1.6370303e-26, 3.9350903e-23, 0.0000000e+00, 0.0000000e+00,
#        1.3622669e-16, 2.8496811e-22, 0.0000000e+00, 5.8468520e-15,
#        4.9939868e-11, 5.1258397e-19, 1.0000000e+00, 9.9999940e-01,
#        0.0000000e+00, 0.0000000e+00, 6.5891322e-30, 0.0000000e+00,
#        0.0000000e+00, 8.9788060e-36, 4.8928037e-36, 1.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        1.0000000e+00], dtype=float32)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
def plot_cm(labels, predictions, p=9.9997638e-01):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Matriz de confusion @{:.2f}'.format(p))
  plt.ylabel('Valor actual')
  plt.xlabel('Valor predecido')

  print('Detección de una transacción legítima (Verdaderos Positivos): ', cm[0][0])
  print('Transacción legítima incorrectamente detectatada (Falso Negativo): ', cm[0][1])
  print('Transacción fraudulenta incorrectamente detectada (Falso Positivo): ', cm[1][0])
  print('Transacción fraudulenta detectada: ', cm[1][1])
  print('Total de transacciones del titular: ', np.sum(cm[1]))

# %%
plot_cm(y_train[2018,0,:], Q[2018,0,:])
# Out:
# Detección de una transacción legítima (Verdaderos Positivos):  40
# Transacción legítima incorrectamente detectatada (Falso Negativo):  0
# Transacción fraudulenta incorrectamente detectada (Falso Positivo):  0
# Transacción fraudulenta detectada:  9
# Total de transacciones del titular:  9

# %%
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('Falsos Positivos')
    plt.ylabel('Verdaderos Positivos')
    plt.title('Curva ROC')
    plt.legend()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('Falsos Positivos')
    plt.ylabel('Verdaderos Positivos')
    plt.title('Transacciones Fraudulentas titular 5000')
    plt.legend()
    plt.show()
    
data_X, cls_lab = make_classification(n_samples=2100, n_classes=2, weights=[1.939,1.2959], random_state=2)
train_X, test_X, train_y, test_y = train_test_split(data_X, cls_lab, test_size=0.4, random_state=3)

model =RandomForestClassifier()
model.fit(train_X, train_y)

prob = model.predict_proba(test_X)
prob = prob[:, 1]
fper, tper, thresholds = roc_curve(test_y, prob)
plot_roc_curve(fper, tper)
